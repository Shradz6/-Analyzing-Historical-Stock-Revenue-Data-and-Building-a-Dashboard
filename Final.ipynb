# %%
# Import necessary libraries
import yfinance as yf
import matplotlib.pyplot as plt

# Function to make a simple stock graph
def make_graph(x, y, title):
    plt.figure(figsize=(10, 6))
    plt.plot(x, y, label='Stock Price')
    plt.title(title)
    plt.xlabel('Date')
    plt.ylabel('Stock Price')
    plt.legend()
    plt.grid(True)

# %%
tesla_data = yf.download('TSLA', start='2022-01-01', end='2023-01-01')
tesla_data.reset_index(inplace=True)
tesla_data.to_csv('tesla_stock_data.csv')
tesla_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                        Date        Open        High         Low       Close  \
# 0 2022-01-03 00:00:00-05:00  382.583344  400.356659  378.679993  399.926666
# 1 2022-01-04 00:00:00-05:00  396.516663  402.666656  374.350006  383.196655
# 2 2022-01-05 00:00:00-05:00  382.216675  390.113342  360.336670  362.706665
# 3 2022-01-06 00:00:00-05:00  359.000000  362.666656  340.166656  354.899994
# 4 2022-01-07 00:00:00-05:00  360.123322  360.309998  336.666656  342.320007
#
#     Adj Close     Volume
# 0  399.926666  103931400
# 1  383.196655  100248300
# 2  362.706665   80119800
# 3  354.899994   90336600
# 4  342.320007   84164700

# %%
# Out:
# Failed to retrieve data. Status code: 404
# Web scraping did not succeed. Check the error messages above for more information.

# %%
tesla_revenue.tail()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1481/899846489.py in <module>
# ----> 1 tesla_revenue.tail()
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
gme_data = yf.download('GME', start='2022-01-01', end='2023-01-01')
gme_data.reset_index(inplace=True)
gme_data.to_csv('gme_stock_data.csv')
gme_data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                        Date       Open       High        Low      Close  \
# 0 2022-01-03 00:00:00-05:00  37.307499  39.845001  37.302502  38.209999
# 1 2022-01-04 00:00:00-05:00  38.042500  38.247501  35.762501  37.227501
# 2 2022-01-05 00:00:00-05:00  37.097500  37.212502  32.287498  32.342499
# 3 2022-01-06 00:00:00-05:00  33.209999  34.424999  30.285000  32.757500
# 4 2022-01-07 00:00:00-05:00  39.942501  40.077499  33.125000  35.154999
#
#    Adj Close    Volume
# 0  38.209999   5654800
# 1  37.227501   7339600
# 2  32.342499  13585600
# 3  32.757500  24206000
# 4  35.154999  48549200

# %%
gme_revenue.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1481/374026413.py in <module>
# ----> 1 gme_revenue.tail()
#
# NameError: name 'gme_revenue' is not defined

# %%
make_graph(tesla_data['Date'], tesla_data['Close'], title='Tesla Stock Data')
plt.show()

# %% [markdown]
# make_graph(gme_data['Date'], gme_data['Close'], title='GameStop Stock Data')
# plt.show()
